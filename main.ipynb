# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

# Carrega as variáveis de segurança do seu arquivo .env
load_dotenv()

# Puxa a chave exata que você colou lá
minha_chave = os.getenv("API_KEY")

# Conecta o seu projeto aos servidores do Google
genai.configure(api_key=minha_chave)

print("✅ Conexão configurada com sucesso!")
# Out:
# Hello world!
